# %% [markdown]
# <a href="https://colab.research.google.com/github/Wellington188/Eleicao_Londrina_2020/blob/main/Londrina_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Importando os dados e blibiotecas**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
candidatos_PR = pd.read_csv("/content/drive/My Drive/Data_Eleições/consulta_cand_2020_PR.csv", sep=';', encoding='iso-8859-1');

# %%
sns.set()

# %%
candidatos_PR
# Out:
#        DT_GERACAO  ... ST_CANDIDATO_INSERIDO_URNA
# 0      05/10/2020  ...                        NÃO
# 1      05/10/2020  ...                        NÃO
# 2      05/10/2020  ...                        NÃO
# 3      05/10/2020  ...                        NÃO
# 4      05/10/2020  ...                        NÃO
# ...           ...  ...                        ...
# 36710  05/10/2020  ...                        NÃO
# 36711  05/10/2020  ...                        NÃO
# 36712  05/10/2020  ...                        NÃO
# 36713  05/10/2020  ...                        NÃO
# 36714  05/10/2020  ...                        NÃO
#
# [36715 rows x 63 columns]

# %% [markdown]
# Filtrar candidatos de londrina.

# %%
candidatos_LONDRINA = candidatos_PR[candidatos_PR.NM_UE == 'LONDRINA']
candidatos_LONDRINA
# Out:
#        DT_GERACAO  ... ST_CANDIDATO_INSERIDO_URNA
# 15     05/10/2020  ...                        NÃO
# 272    05/10/2020  ...                        NÃO
# 306    05/10/2020  ...                        NÃO
# 336    05/10/2020  ...                        NÃO
# 354    05/10/2020  ...                        NÃO
# ...           ...  ...                        ...
# 36523  05/10/2020  ...                        NÃO
# 36621  05/10/2020  ...                        NÃO
# 36655  05/10/2020  ...                        NÃO
# 36659  05/10/2020  ...                        NÃO
# 36695  05/10/2020  ...                        NÃO
#
# [588 rows x 63 columns]

# %% [markdown]
# Verificar candiatos que irão se reeleger.

# %%
candidatos_LONDRINA['ST_REELEICAO'].value_counts(normalize=True)*100
# Out:
# N    97.44898
# S     2.55102
# Name: ST_REELEICAO, dtype: float64

# %%
candidatos_LONDRINA[candidatos_LONDRINA['ST_REELEICAO'] == 'S']
# Out:
#        DT_GERACAO  ... ST_CANDIDATO_INSERIDO_URNA
# 577    05/10/2020  ...                        NÃO
# 5506   05/10/2020  ...                        NÃO
# 6887   05/10/2020  ...                        NÃO
# 11087  05/10/2020  ...                        NÃO
# 15326  05/10/2020  ...                        NÃO
# 16488  05/10/2020  ...                        NÃO
# 17609  05/10/2020  ...                        NÃO
# 18954  05/10/2020  ...                        NÃO
# 19404  05/10/2020  ...                        NÃO
# 19460  05/10/2020  ...                        NÃO
# 20426  05/10/2020  ...                        NÃO
# 24748  05/10/2020  ...                        NÃO
# 25201  05/10/2020  ...                        NÃO
# 31090  05/10/2020  ...                        NÃO
# 35297  05/10/2020  ...                        NÃO
#
# [15 rows x 63 columns]

# %% [markdown]
# **Analisar o GRAU de escolaridade dos candidatos de Londrina**

# %%
candidatos_LONDRINA['DS_GRAU_INSTRUCAO'].value_counts(normalize=True)*100
# Out:
# SUPERIOR COMPLETO                38.605442
# ENSINO MÉDIO COMPLETO            35.204082
# ENSINO FUNDAMENTAL COMPLETO      10.204082
# SUPERIOR INCOMPLETO               7.993197
# ENSINO FUNDAMENTAL INCOMPLETO     3.571429
# ENSINO MÉDIO INCOMPLETO           2.721088
# LÊ E ESCREVE                      1.700680
# Name: DS_GRAU_INSTRUCAO, dtype: float64

# %%
candidatos_LONDRINA['SG_PARTIDO'].value_counts(normalize=True)*100
# Out:
# PDT              5.272109
# PROS             5.272109
# PMB              5.102041
# PSDB             4.931973
# DC               4.931973
# PATRIOTA         4.931973
# PL               4.931973
# PSB              4.761905
# PP               4.761905
# PV               4.421769
# SOLIDARIEDADE    4.421769
# MDB              4.421769
# PODE             4.251701
# PSC              4.251701
# PSL              4.081633
# PTB              4.081633
# AVANTE           3.911565
# REPUBLICANOS     3.911565
# DEM              3.571429
# PMN              3.401361
# CIDADANIA        3.231293
# PSD              2.891156
# PT               1.870748
# PSOL             0.850340
# PC do B          0.850340
# PRTB             0.510204
# PCO              0.170068
# Name: SG_PARTIDO, dtype: float64

# %% [markdown]
# Análise de escolaridade por partido.

# %%
candidatos_LONDRINA[candidatos_LONDRINA['SG_PARTIDO']=='PT']['DS_GRAU_INSTRUCAO'].value_counts(normalize=True).plot(kind='bar', title='Grau de Instrucao Candidatos 2020');

# %%
candidatos_LONDRINA[candidatos_LONDRINA['SG_PARTIDO']=='PC do B']['DS_GRAU_INSTRUCAO'].value_counts(normalize=True).plot(kind='bar', title='Grau de Instrucao Candidatos PC do B 2020');

# %%
candidatos_LONDRINA[candidatos_LONDRINA['SG_PARTIDO']=='PSL']['DS_GRAU_INSTRUCAO'].value_counts(normalize=True).plot(kind='bar', title='Grau de Instrucao Candidatos PSL 2020');

# %%
candidatos_LONDRINA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 588 entries, 15 to 36695
# Data columns (total 63 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   DT_GERACAO                     588 non-null    object
#  1   HH_GERACAO                     588 non-null    object
#  2   ANO_ELEICAO                    588 non-null    int64
#  3   CD_TIPO_ELEICAO                588 non-null    int64
#  4   NM_TIPO_ELEICAO                588 non-null    object
#  5   NR_TURNO                       588 non-null    int64
#  6   CD_ELEICAO                     588 non-null    int64
#  7   DS_ELEICAO                     588 non-null    object
#  8   DT_ELEICAO                     588 non-null    object
#  9   TP_ABRANGENCIA                 588 non-null    object
#  10  SG_UF                          588 non-null    object
#  11  SG_UE                          588 non-null    int64
# ...

# %%
candidatos_LONDRINA['DS_COR_RACA'].value_counts(normalize=True).plot(kind='bar', title='Etnias presentes em eleições 2020');

# %%
candidatos_LONDRINA[candidatos_LONDRINA['SG_PARTIDO']=='PC do B']['DS_COR_RACA'].value_counts(normalize=True).plot(kind='bar', title='Etnias presentes em PC do B 2020');

# %%
(candidatos_LONDRINA[candidatos_LONDRINA['SG_PARTIDO']=='PSL']['DS_COR_RACA'].value_counts(normalize=True)*100).plot(kind='bar', title='Etnias presentes em PSL 2020');

# %%
figbi, axesbi = plt.subplots(figsize=(16, 10))
candidatos_LONDRINA.groupby('SG_PARTIDO')['NR_IDADE_DATA_POSSE'].mean().sort_values().plot(kind='barh',xlim=[0,100]);
